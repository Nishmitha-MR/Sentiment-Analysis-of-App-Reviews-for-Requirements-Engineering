# %% [markdown]
# # INSTALLING LIBRARIES

# %%
# !pip install pyngrok

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# Google Drive Integration
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Import required libraries
import os
import http.server
import socketserver
from pyngrok import ngrok

# %% [markdown]
# # WEB SERVER SETUP

# %%
# Authenticate Ngrok (Replace the token with your own)
# !ngrok authtoken 2knEnzS3l3TNLz9R8o8pJjEXJCl_4dY6bK1L7DXnQ65mggapf

# Set the directory where your HTML and CSS files are located in Google Drive
os.chdir('/content/drive/MyDrive/ColabNotebooks/Dissertation24/UI')

# Set the port number for the server
PORT = 8000

# Create a public URL using Ngrok for the local server
public_url = ngrok.connect(PORT)
print(f"Public URL: {public_url}")

# Create and start a simple HTTP server to serve files from the specified directory
Handler = http.server.SimpleHTTPRequestHandler

with socketserver.TCPServer(("", PORT), Handler) as httpd:
    print(f"Serving at port {PORT}")
    httpd.serve_forever()
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml
# Public URL: NgrokTunnel: "https://6f29-34-46-74-7.ngrok-free.app" -> "http://localhost:8000"
# Serving at port 8000
# 127.0.0.1 - - [20/Aug/2024 17:18:33] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/Distribution_of_Mapped_Predictions_RoBERTa.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/plot_predicted_labels_distribution_Naive_Bayes_RoBERTa.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/plot_predicted_labels_distribution_Perceptron_RoBERTa.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/plot_predicted_labels_distribution_BERT_RoBERTa.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/plot_predicted_labels_distribution_Linear_SVM_RoBERTa.png HTTP/1.1" 200 -
# 127.0.0.1 - - [20/Aug/2024 17:18:34] "GET /images/Distribution_of_Mapped_Predictions_Manual.png HTTP/1.1" 200 -
# ...
