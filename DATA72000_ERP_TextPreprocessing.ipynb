# %% [markdown]
# # INSTALLING LIBRARIES

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-2.12.1-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from emoji) (4.12.2)
# Downloading emoji-2.12.1-py3-none-any.whl (431 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 431.4/431.4 kB 5.1 MB/s eta 0:00:00
# Installing collected packages: emoji
# Successfully installed emoji-2.12.1

# %% [markdown]
# # IMPORTING LIBRARIES

# %%
# Google Drive Integration
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Data manipulation and handling
import pandas as pd

# Regular expressions and text processing
import re
import emoji
import html

# Natural Language Processing (NLP)
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# For sentiment analysis and text processing
from textblob import TextBlob

# Machine Learning model preparation
from sklearn.model_selection import train_test_split

# %%
# Downloading necessary NLTK data
nltk.download('punkt')  # Tokenizer
nltk.download('stopwords')  # Stopwords list
nltk.download('wordnet')  # WordNet lemmatizer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %% [markdown]
# # LOADING DATASETS

# %%
app_reviews_df = pd.read_csv('/content/drive/MyDrive/Dissertation24/All_Reviews.csv')
manually_labelled_df = pd.read_csv('/content/drive/MyDrive/Dissertation24/ManuallyLabelledReviews.csv')
app_reviews_df_copy = app_reviews_df.copy()
manually_labelled_df_copy = manually_labelled_df.copy()

# %%
print(app_reviews_df_copy)
print(manually_labelled_df_copy)
# Out:
#                                    reviewId           userName  \
# 0      154c1b8c-f147-4ebd-afc5-16170b08dfad      A Google user
# 1      e1adb357-a035-4d5e-8b17-32745dc047c6      A Google user
# 2      41d2c39c-1027-4677-8451-9aa6b3b714c7      A Google user
# 3      f9c74575-b297-40c7-8cf0-57ae7dfe0442      A Google user
# 4      893f9c71-c0eb-417d-a0e2-fc849f9e6b6c      A Google user
# ...                                     ...                ...
# 49995  11d59964-62d9-4e6e-98ec-49d7a1edee22      A Google user
# 49996  d827fd17-f39e-4233-9f1e-a5e663847430      A Google user
# 49997  4bc4b36b-9153-4f6e-a463-05326b6d1bcf      A Google user
# 49998  8ed1a88f-1de3-49a4-a083-668517b56741  black octobermoon
# 49999  ac61809e-ac1e-499f-b71c-bf5dbb2fbb15      A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 49995  https://play-lh.googleusercontent.com/EGemoI2N...
# 49996  https://play-lh.googleusercontent.com/EGemoI2N...
# 49997  https://play-lh.googleusercontent.com/EGemoI2N...
# 49998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 49999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      This use to be a great app, the only thing gre...      4
# 1      WhatsApp for Android is my go-to messaging app...      5
# 2      Good app. Although it could be made a lot bett...      3
# 3      I recently got a new Android phone. Tried to v...      1
# 4      It is extremely disappointing since Facebook g...      1
# ...                                                  ...    ...
# 49995  Great app, it usually helps me calm myself dow...      5
# 49996  The download function doesn't work properly. E...      2
# 49997  Used to use this on a daily basis. Now all the...      1
# 49998  I used to love this ap there were lots of opti...      2
# 49999  Love the app but mostly only used it for the s...      3
#
#        thumbsUpCount reviewCreatedVersion                   at  \
# 0                375           2.24.14.81  2024-07-25 20:14:08
# 1               6769           2.24.13.77  2024-07-16 21:50:12
# 2                 56            2.24.9.78  2024-07-26 17:14:18
# 3                917           2.24.13.77  2024-07-09 09:56:16
# 4              21544            2.24.9.78  2024-05-22 10:55:56
# ...              ...                  ...                  ...
# 49995              0                  NaN  2019-12-26 10:01:22
# 49996              0               3.33.0  2019-09-05 13:06:44
# 49997             30               3.40.0  2019-10-20 04:12:22
# 49998              4               4.17.0  2020-10-25 15:23:35
# 49999              0               3.39.0  2020-04-26 21:40:31
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 49995                                                NaN                  NaN
# 49996  Thank you for reaching out. We are sorry for t...  2019-09-05 13:40:35
# 49997  Thanks for reaching out. We appreciate your fe...  2019-10-20 16:49:09
# 49998                                                NaN                  NaN
# 49999                                                NaN                  NaN
#
#        appVersion                         source
# 0      2.24.14.81             WhatsApp Messenger
# 1      2.24.13.77             WhatsApp Messenger
# 2       2.24.9.78             WhatsApp Messenger
# 3      2.24.13.77             WhatsApp Messenger
# 4       2.24.9.78             WhatsApp Messenger
# ...           ...                            ...
# 49995         NaN  Headspace: Meditation & Sleep
# 49996      3.33.0  Headspace: Meditation & Sleep
# 49997      3.40.0  Headspace: Meditation & Sleep
# 49998      4.17.0  Headspace: Meditation & Sleep
# 49999      3.39.0  Headspace: Meditation & Sleep
#
# [50000 rows x 12 columns]
#                                                 content  length  positive  \
# 0     ver 12.14.1, delete all data menu not function...      23         2
# 1     used to be good. too many pop ups, ads article...      13         2
# 2     i couldn't even sign up i contacted fliphelp n...      12         1
# 3     for what i know about this app and it works re...      19         3
# 4     love the app, though on occasions what is play...      95         3
# ...                                                 ...     ...       ...
# 9097  Personally i love the feature in which i can t...     310         3
# 9098  Seems to be a bug or something on android vers...     245         1
# 9099  This is a very good app, but you cannot downlo...     487         2
# 9100  Its actually a nice app but these days i have ...     307         2
# 9101  this app is very efficient and flexible, it ad...     303         5
#
#       negative     label
# 0           -2   neutral
# 1           -4  negative
# 2           -3  negative
# 3           -1  positive
# 4           -5  negative
# ...        ...       ...
# 9097        -1  positive
# 9098        -1   neutral
# 9099        -2   neutral
# 9100        -2   neutral
# 9101        -1  positive
#
# [9102 rows x 5 columns]

# %%
app_reviews_df_copy.info()
manually_labelled_df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              50000 non-null  object
#  1   userName              50000 non-null  object
#  2   userImage             50000 non-null  object
#  3   content               49999 non-null  object
#  4   score                 50000 non-null  int64
#  5   thumbsUpCount         50000 non-null  int64
#  6   reviewCreatedVersion  46735 non-null  object
#  7   at                    50000 non-null  object
#  8   replyContent          9387 non-null   object
#  9   repliedAt             9387 non-null   object
#  10  appVersion            46735 non-null  object
#  11  source                50000 non-null  object
# dtypes: int64(2), object(10)
# memory usage: 4.6+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9102 entries, 0 to 9101
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   content   9102 non-null   object
#  1   length    9102 non-null   int64
#  2   positive  9102 non-null   int64
#  3   negative  9102 non-null   int64
#  4   label     9102 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 355.7+ KB

# %% [markdown]
# # TEXT PREPROCESSING

# %%
def clean_whitespace(text):
    # Remove leading and trailing white spaces
    text = text.strip()
    # Split the text by whitespace and rejoin with a single space
    text = ' '.join(text.split())
    return text

# Remove missing values
app_reviews_df_copy = app_reviews_df_copy.dropna(subset=['content'])
manually_labelled_df_copy = manually_labelled_df_copy.dropna(subset=['content'])

# Remove duplicates values
app_reviews_df_copy = app_reviews_df_copy.drop_duplicates(subset=['content'])
manually_labelled_df_copy = manually_labelled_df_copy.drop_duplicates(subset=['content'])

# Replace missing or null values in the 'score' column with 0
app_reviews_df_copy['score'] = app_reviews_df_copy['score'].fillna(0)

# Modify the 'at' column to keep only the date part
app_reviews_df_copy['at'] = pd.to_datetime(app_reviews_df_copy['at']).dt.date

# Apply the clean_whitespace function to the 'content' column
app_reviews_df_copy['content'] = app_reviews_df_copy['content'].apply(clean_whitespace)
manually_labelled_df_copy['content'] = manually_labelled_df_copy['content'].apply(clean_whitespace)

# Convert 'content' columns to string
app_reviews_df_copy['content'] = app_reviews_df_copy['content'].astype('string')

# Filter out rows where the length of the 'content' is 0
app_reviews_df_copy = app_reviews_df_copy[app_reviews_df_copy['content'].apply(len) > 0]
manually_labelled_df_copy = manually_labelled_df_copy[manually_labelled_df_copy['content'].apply(len) > 0]

# Convert 'label' column to lowercase
manually_labelled_df_copy['label'] = manually_labelled_df_copy['label'].str.lower()

app_reviews_df_copy
# Out:
#                                    reviewId           userName  \
# 0      154c1b8c-f147-4ebd-afc5-16170b08dfad      A Google user
# 1      e1adb357-a035-4d5e-8b17-32745dc047c6      A Google user
# 2      41d2c39c-1027-4677-8451-9aa6b3b714c7      A Google user
# 3      f9c74575-b297-40c7-8cf0-57ae7dfe0442      A Google user
# 4      893f9c71-c0eb-417d-a0e2-fc849f9e6b6c      A Google user
# ...                                     ...                ...
# 49995  11d59964-62d9-4e6e-98ec-49d7a1edee22      A Google user
# 49996  d827fd17-f39e-4233-9f1e-a5e663847430      A Google user
# 49997  4bc4b36b-9153-4f6e-a463-05326b6d1bcf      A Google user
# 49998  8ed1a88f-1de3-49a4-a083-668517b56741  black octobermoon
# 49999  ac61809e-ac1e-499f-b71c-bf5dbb2fbb15      A Google user
#
#                                                userImage  \
# 0      https://play-lh.googleusercontent.com/EGemoI2N...
# 1      https://play-lh.googleusercontent.com/EGemoI2N...
# 2      https://play-lh.googleusercontent.com/EGemoI2N...
# 3      https://play-lh.googleusercontent.com/EGemoI2N...
# 4      https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                  ...
# 49995  https://play-lh.googleusercontent.com/EGemoI2N...
# 49996  https://play-lh.googleusercontent.com/EGemoI2N...
# 49997  https://play-lh.googleusercontent.com/EGemoI2N...
# 49998  https://play-lh.googleusercontent.com/a/ACg8oc...
# 49999  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                  content  score  \
# 0      This use to be a great app, the only thing gre...      4
# 1      WhatsApp for Android is my go-to messaging app...      5
# 2      Good app. Although it could be made a lot bett...      3
# 3      I recently got a new Android phone. Tried to v...      1
# 4      It is extremely disappointing since Facebook g...      1
# ...                                                  ...    ...
# 49995  Great app, it usually helps me calm myself dow...      5
# 49996  The download function doesn't work properly. E...      2
# 49997  Used to use this on a daily basis. Now all the...      1
# 49998  I used to love this ap there were lots of opti...      2
# 49999  Love the app but mostly only used it for the s...      3
#
#        thumbsUpCount reviewCreatedVersion          at  \
# 0                375           2.24.14.81  2024-07-25
# 1               6769           2.24.13.77  2024-07-16
# 2                 56            2.24.9.78  2024-07-26
# 3                917           2.24.13.77  2024-07-09
# 4              21544            2.24.9.78  2024-05-22
# ...              ...                  ...         ...
# 49995              0                  NaN  2019-12-26
# 49996              0               3.33.0  2019-09-05
# 49997             30               3.40.0  2019-10-20
# 49998              4               4.17.0  2020-10-25
# 49999              0               3.39.0  2020-04-26
#
#                                             replyContent            repliedAt  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 49995                                                NaN                  NaN
# 49996  Thank you for reaching out. We are sorry for t...  2019-09-05 13:40:35
# 49997  Thanks for reaching out. We appreciate your fe...  2019-10-20 16:49:09
# 49998                                                NaN                  NaN
# 49999                                                NaN                  NaN
#
#        appVersion                         source
# 0      2.24.14.81             WhatsApp Messenger
# 1      2.24.13.77             WhatsApp Messenger
# 2       2.24.9.78             WhatsApp Messenger
# 3      2.24.13.77             WhatsApp Messenger
# 4       2.24.9.78             WhatsApp Messenger
# ...           ...                            ...
# 49995         NaN  Headspace: Meditation & Sleep
# 49996      3.33.0  Headspace: Meditation & Sleep
# 49997      3.40.0  Headspace: Meditation & Sleep
# 49998      4.17.0  Headspace: Meditation & Sleep
# 49999      3.39.0  Headspace: Meditation & Sleep
#
# [49117 rows x 12 columns]

# %%
manually_labelled_df_copy
# Out:
#                                                 content  length  positive  \
# 0     ver 12.14.1, delete all data menu not function...      23         2
# 1     used to be good. too many pop ups, ads article...      13         2
# 2     i couldn't even sign up i contacted fliphelp n...      12         1
# 3     for what i know about this app and it works re...      19         3
# 4     love the app, though on occasions what is play...      95         3
# ...                                                 ...     ...       ...
# 9097  Personally i love the feature in which i can t...     310         3
# 9098  Seems to be a bug or something on android vers...     245         1
# 9099  This is a very good app, but you cannot downlo...     487         2
# 9100  Its actually a nice app but these days i have ...     307         2
# 9101  this app is very efficient and flexible, it ad...     303         5
#
#       negative     label
# 0           -2   neutral
# 1           -4  negative
# 2           -3  negative
# 3           -1  positive
# 4           -5  negative
# ...        ...       ...
# 9097        -1  positive
# 9098        -1   neutral
# 9099        -2   neutral
# 9100        -2   neutral
# 9101        -1  positive
#
# [9102 rows x 5 columns]

# %% [markdown]
# ## SAMPLE A DATASET FOR MANUAL LABELLING

# %%
# Function to sample data
def sample_data(group):
    n_samples = 50
    return group.sample(n=min(n_samples, len(group)), random_state=1)

# Apply the sampling function to each group determined by the 'source' column
sampled_data = app_reviews_df_copy.groupby('source').apply(sample_data).reset_index(drop=True)

# Calculate the length of each content
sampled_data['length'] = sampled_data['content'].apply(len)

sampled_data
# Out:
#                                  reviewId       userName  \
# 0    30aacbea-3411-4b52-96db-6fb56adc0be1  A Google user
# 1    da910a0a-eaef-4e6b-8def-f7a8aad268ac  A Google user
# 2    fa1778d9-2048-4864-a9d7-389e89f2d8eb  A Google user
# 3    13c2711b-f373-4373-b6c3-46fbbd0062de  A Google user
# 4    cf24dbec-4aa3-463c-9ce7-67c3ea7f2744  A Google user
# ..                                    ...            ...
# 495  5cdea7b6-b53e-46fa-bb79-127c58046bb9  A Google user
# 496  50c50cba-c54e-4b01-a56e-9cd4c16497ce  A Google user
# 497  6ee99a2a-187a-48bb-a55a-a5a3456ad79c  A Google user
# 498  1ba4866b-0da7-4ff4-9fe8-424650506012  A Google user
# 499  0c4c22b6-84b1-482b-bdbd-cd995076693e  A Google user
#
#                                              userImage  \
# 0    https://play-lh.googleusercontent.com/EGemoI2N...
# 1    https://play-lh.googleusercontent.com/EGemoI2N...
# 2    https://play-lh.googleusercontent.com/EGemoI2N...
# 3    https://play-lh.googleusercontent.com/EGemoI2N...
# 4    https://play-lh.googleusercontent.com/EGemoI2N...
# ..                                                 ...
# 495  https://play-lh.googleusercontent.com/EGemoI2N...
# 496  https://play-lh.googleusercontent.com/EGemoI2N...
# 497  https://play-lh.googleusercontent.com/EGemoI2N...
# 498  https://play-lh.googleusercontent.com/EGemoI2N...
# 499  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                content  score  thumbsUpCount  \
# 0    Ads used to be bearable, but now they added in...      1              4
# 1    Nice but does put on some bias when writing th...      4              1
# 2    Nice interface. Better content than other news...      5              2
# 3    WHY DO NEWS ORGANIZATION INSIST ON MAKING MY O...      3            189
# 4    The news reporting is great. The new design of...      2              2
# ..                                                 ...    ...            ...
# 495  Personally i love the feature in which i can t...      5            159
# 496  Seems to be a bug or something on android vers...      4             21
# 497  This is a very good app, but you cannot downlo...      2             22
# 498  Its actually a nice app but these days i have ...      1              6
# 499  this app is very efficient and flexible, it ad...      5             56
#
#     reviewCreatedVersion          at replyContent repliedAt    appVersion  \
# 0           4.7.1.13 GNL  2020-10-12          NaN       NaN  4.7.1.13 GNL
# 1              5.6.0.100  2019-05-11          NaN       NaN     5.6.0.100
# 2                 5.18.0  2021-08-25          NaN       NaN        5.18.0
# 3                8.0.1.3  2024-04-04          NaN       NaN       8.0.1.3
# 4             7.1.0.5385  2023-10-27          NaN       NaN    7.1.0.5385
# ..                   ...         ...          ...       ...           ...
# 495           2.24.11.79  2024-06-17          NaN       NaN    2.24.11.79
# 496           2.24.12.78  2024-06-21          NaN       NaN    2.24.12.78
# 497           2.24.12.78  2024-06-28          NaN       NaN    2.24.12.78
# 498           2.24.13.77  2024-07-09          NaN       NaN    2.24.13.77
# 499           2.24.10.85  2024-05-25          NaN       NaN    2.24.10.85
#
#                         source  length
# 0    BBC: World News & Stories     188
# 1    BBC: World News & Stories     119
# 2    BBC: World News & Stories     133
# 3    BBC: World News & Stories     188
# 4    BBC: World News & Stories     186
# ..                         ...     ...
# 495         WhatsApp Messenger     310
# 496         WhatsApp Messenger     245
# 497         WhatsApp Messenger     487
# 498         WhatsApp Messenger     307
# 499         WhatsApp Messenger     303
#
# [500 rows x 13 columns]

# %%
# Remove the sampled rows from app_reviews_df_copy
app_reviews_df_copy = app_reviews_df_copy[~app_reviews_df_copy['reviewId'].isin(sampled_data['reviewId'])]

# Select only the specified columns: content, score, at, and source
app_reviews_df_copy = app_reviews_df_copy[['content', 'score', 'at', 'source']]
sampled_data = sampled_data[['content','score', 'at', 'source', 'length',]]

# %%
print(app_reviews_df_copy.shape)
print(sampled_data.shape)
# Out:
# (48617, 4)
# (500, 5)

# %%
sampled_data
# Out:
#                                                content  score          at  \
# 0    Ads used to be bearable, but now they added in...      1  2020-10-12
# 1    Nice but does put on some bias when writing th...      4  2019-05-11
# 2    Nice interface. Better content than other news...      5  2021-08-25
# 3    WHY DO NEWS ORGANIZATION INSIST ON MAKING MY O...      3  2024-04-04
# 4    The news reporting is great. The new design of...      2  2023-10-27
# ..                                                 ...    ...         ...
# 495  Personally i love the feature in which i can t...      5  2024-06-17
# 496  Seems to be a bug or something on android vers...      4  2024-06-21
# 497  This is a very good app, but you cannot downlo...      2  2024-06-28
# 498  Its actually a nice app but these days i have ...      1  2024-07-09
# 499  this app is very efficient and flexible, it ad...      5  2024-05-25
#
#                         source  length
# 0    BBC: World News & Stories     188
# 1    BBC: World News & Stories     119
# 2    BBC: World News & Stories     133
# 3    BBC: World News & Stories     188
# 4    BBC: World News & Stories     186
# ..                         ...     ...
# 495         WhatsApp Messenger     310
# 496         WhatsApp Messenger     245
# 497         WhatsApp Messenger     487
# 498         WhatsApp Messenger     307
# 499         WhatsApp Messenger     303
#
# [500 rows x 5 columns]

# %%
# Save the sampled data to a new CSV file
sampled_data.to_csv('/content/drive/MyDrive/Dissertation24/SampleReviews_ManualLabelling.csv', index=False)
print("Reviews have been saved to SampleReviews_ManuallyLabelled.csv")
# Out:
# Reviews have been saved to SampleReviews_ManuallyLabelled.csv

# %% [markdown]
# ## DATA CLEANING

# %%
# Define comprehensive text cleaning function
def clean_text(text):

    # Convert to lowercase
    text = text.lower()

    # Remove emojis
    text = emoji.replace_emoji(text, replace='')

    # Remove URLs, mentions, and hashtags
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'@\w+', '', text)
    text = re.sub(r'#\w+', '', text)

    # Remove special characters and punctuation
    text = re.sub(r'[^\w\s]', '', text)

    # Remove numbers
    text = re.sub(r'\d+', '', text)

    # Decode HTML entities
    text = html.unescape(text)

    # Tokenize the text
    tokens = word_tokenize(text)

    # Remove stop words
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]

    # Lemmatization
    lemmatizer = WordNetLemmatizer()
    tokens = [lemmatizer.lemmatize(word) for word in tokens]

    text = ' '.join(tokens)

    return text

# Apply text cleaning
app_reviews_df_copy['content'] = app_reviews_df_copy['content'].apply(clean_text)
manually_labelled_df_copy['content'] = manually_labelled_df_copy['content'].apply(clean_text)

# Calculate the length of each content
app_reviews_df_copy['length'] = app_reviews_df_copy['content'].apply(len)
manually_labelled_df_copy['length'] = manually_labelled_df_copy['content'].apply(len)

# Filter out rows where the length of the 'content' is 0
app_reviews_df_copy = app_reviews_df_copy[app_reviews_df_copy['length'] > 0]
manually_labelled_df_copy = manually_labelled_df_copy[manually_labelled_df_copy['length'] > 0]

app_reviews_df_copy
# Out:
#                                                  content  score          at  \
# 0      use great app thing great end end encryption u...      4  2024-07-25
# 1      whatsapp android goto messaging app incredibly...      5  2024-07-16
# 2      good app although could made lot better visual...      3  2024-07-26
# 3      recently got new android phone tried verify ne...      1  2024-07-09
# 4      extremely disappointing since facebook got inv...      1  2024-05-22
# ...                                                  ...    ...         ...
# 49995  great app usually help calm always understood ...      5  2019-12-26
# 49996  download function doesnt work properly even th...      2  2019-09-05
# 49997  used use daily basis thing listened locked beh...      1  2019-10-20
# 49998  used love ap lot option still available free s...      2  2020-10-25
# 49999  love app mostly used sleepcasts cant use expen...      3  2020-04-26
#
#                               source  length
# 0                 WhatsApp Messenger     244
# 1                 WhatsApp Messenger     234
# 2                 WhatsApp Messenger     250
# 3                 WhatsApp Messenger     262
# 4                 WhatsApp Messenger     307
# ...                              ...     ...
# 49995  Headspace: Meditation & Sleep     209
# 49996  Headspace: Meditation & Sleep     136
# 49997  Headspace: Meditation & Sleep     197
# 49998  Headspace: Meditation & Sleep     269
# 49999  Headspace: Meditation & Sleep     151
#
# [48600 rows x 5 columns]

# %%
manually_labelled_df_copy
# Out:
#                                                 content  length  positive  \
# 0     ver delete data menu function data still chat ...      78         2
# 1     used good many pop ups ad article dont load an...      51         2
# 2        couldnt even sign contacted fliphelp mail till      46         1
# 3     know app work really good find exactly youre l...      52         3
# 4     love app though occasion played something inte...     266         3
# ...                                                 ...     ...       ...
# 9097  personally love feature text also meta ai howe...     164         3
# 9098  seems bug something android version trying quo...     163         1
# 9099  good app download status back bring feature co...     298         2
# 9100  actually nice app day encoutering lot problem ...     174         2
# 9101  app efficient flexible address immediate need ...     198         5
#
#       negative     label
# 0           -2   neutral
# 1           -4  negative
# 2           -3  negative
# 3           -1  positive
# 4           -5  negative
# ...        ...       ...
# 9097        -1  positive
# 9098        -1   neutral
# 9099        -2   neutral
# 9100        -2   neutral
# 9101        -1  positive
#
# [9102 rows x 5 columns]

# %% [markdown]
# ## SPLITTING CLEANED DATASET INTO TRAIN AND TEST

# %%
# Split the dataset into 80% training and 20% testing
train_df, test_df = train_test_split(app_reviews_df_copy, test_size=0.2, random_state=42)

# %%
# Display the first few rows of the training and testing datasets
print(train_df)
print(test_df)
# Out:
#                                                  content  score          at  \
# 17223                                          fantastic      5  2020-03-14
# 2121   recent update notification function working pr...      1  2024-07-16
# 42384  fantastic app noticed added cost ireland used ...      5  2021-12-04
# 33701  horrible experience ever got contacted deliver...      1  2021-05-20
# 21737  thre mediation fall asleep nice ability wake w...      3  2022-08-08
# ...                                                  ...    ...         ...
# 11401  clear concise comprehensive impartial everythi...      5  2021-10-13
# 46088  great app went ahead purchased subscription us...      4  2019-04-16
# 39446  kyc process broken take long get agent close c...      1  2020-07-01
# 866    although good initiative meta introduce ai act...      3  2024-07-11
# 15957                      best apps bus time thanjs f l      5  2020-10-12
#
#                                source  length
# 17223  Bus Times -Live Public Transit       9
# 2121               WhatsApp Messenger     138
# 42384                      Citymapper      85
# 33701      Deliveroo: Food & Shopping     309
# 21737      Sleep Cycle: Sleep Tracker     139
# ...                               ...     ...
# 11401       BBC: World News & Stories     118
# 46088   Headspace: Meditation & Sleep     194
# 39446     Revolut: Spend, Save, Trade     290
# 866                WhatsApp Messenger     263
# 15957  Bus Times -Live Public Transit      29
#
# [38880 rows x 5 columns]
#                                                  content  score          at  \
# 37515  ive revised rating two reason customer support...      4  2021-07-13
# 12392              go world news recent update ruined ui      2  2024-04-13
# 47267  ive using headspace age meditation excellent a...      4  2020-01-18
# 42252  amazing major city ive used san fran london ti...      5  2020-01-29
# 49345  love app using year find app cluttered maybe p...      4  2023-09-20
# ...                                                  ...    ...         ...
# 35405  excellent card useful like need pay various cu...      4  2020-03-30
# 17766                            accurate quick reliable      5  2018-04-21
# 10691                      keep crashing lacking feature      1  2024-05-28
# 2400   changing design app made much worse switch dar...      1  2024-04-13
# 33289  please fix tipping bug app letting tip max try...      2  2022-12-23
#
#                                source  length
# 37515     Revolut: Spend, Save, Trade     275
# 12392       BBC: World News & Stories      37
# 47267   Headspace: Meditation & Sleep     258
# 42252                      Citymapper      89
# 49345   Headspace: Meditation & Sleep     171
# ...                               ...     ...
# 35405     Revolut: Spend, Save, Trade     306
# 17766  Bus Times -Live Public Transit      23
# 10691       BBC: World News & Stories      29
# 2400               WhatsApp Messenger     192
# 33289      Deliveroo: Food & Shopping     128
#
# [9720 rows x 5 columns]

# %%
# Save all cleaned content to a CSV file
app_reviews_df_copy.to_csv('/content/drive/MyDrive/Dissertation24/Cleaned_Reviews.csv', index=False)
print("Reviews have been saved to Cleaned_Reviews.csv")

train_df.to_csv('/content/drive/MyDrive/Dissertation24/Training_Reviews.csv', index=False)
print("Reviews have been saved to Training_Reviews.csv")

test_df.to_csv('/content/drive/MyDrive/Dissertation24/Testing_Reviews.csv', index=False)
print("Reviews have been saved to Testing_Reviews.csv")
# Out:
# Reviews have been saved to Cleaned_Reviews.csv
# Reviews have been saved to Training_Reviews.csv
# Reviews have been saved to Testing_Reviews.csv

# %%
manually_labelled_df_copy.to_csv('/content/drive/MyDrive/Dissertation24/Cleaned_Manually_Labelled_Reviews.csv', index=False)
print("Reviews have been saved to Cleaned_Manually_Labelled_Reviews.csv")
# Out:
# Reviews have been saved to Cleaned_Manually_Labelled_Reviews.csv
